# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import numpy as np

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
ds.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
ds.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
ds.dtypes
# Out:
# Unnamed: 0            int64
# id_realEstates        int64
# isNew                  bool
# realEstate_name      object
# phone_realEstate    float64
# url_inmueble         object
# rooms               float64
# bathrooms           float64
# surface             float64
# price                 int64
# date                 object
# description          object
# address              object
# country              object
# level1               object
# level2               object
# level3               object
# level4               object
# level5               object
# level6               object
# level7               object
# level8               object
# upperLevel           object
# countryId             int64
# level1Id              int64
# level2Id              int64
# level3Id              int64
# level4Id              int64
# level5Id              int64
# level6Id              int64
# level7Id              int64
# level8Id              int64
# accuracy              int64
# ...

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
ds.drop_duplicates()
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
casa_mas_cara_prueba_3=ds['price'].max()
direccion_max=ds[ds['price']==ds['price'].max()]
address_max=direccion_max['address'].values[0]
print(f"La casa más cara está en {address_max} y cuesta {casa_mas_cara_prueba_3}")
# Out:
# La casa más cara está en El Escorial y cuesta 8500000

# %%
# ds_price_address=ds[['address','price']]
# casa_mas_cara_prueba_1=ds_price_address.loc[ds_price_address['price']==ds_price_address['price'].max()]
# print(f"Dirección y precio de la casa más cara:,{casa_mas_cara_prueba_1}")

# %%
# casa_mas_casa_prueba_2=ds.loc[ds['price']==ds['price'].max()]
# casa_mas_casa_prueba_2

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
casa_mas_barata_prueba_3=ds['price'].min()
direccion_min=ds[ds['price']==ds['price'].min()]
address_min=direccion_min['address'].values[0]
print(f"La casa más cara está en {address_min} y cuesta {casa_mas_barata_prueba_3}")
# Out:
# La casa más cara está en Parla y cuesta 0

# %%
# casa_mas_barata=ds_price_address.loc[ds_price_address['price']==ds_price_address['price'].min()]
# print(f"Dirección y precio de las casa más baratas:,{casa_mas_barata}")

# %%
# casa_mas_barata_prueba_3=ds['price'].min()
# df_min=ds[ds['price']==casa_mas_barata_prueba_3]

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
ds_addres_surface=ds[['address','surface']]

casa_mas_grande=ds_addres_surface.loc[ds_addres_surface['surface']==ds_addres_surface['surface'].max()]
casa_mas_pequeña=ds_addres_surface.loc[ds_addres_surface['surface']==ds_addres_surface['surface'].min()]
print(f"La casa más grande está ubicada en:")
print(casa_mas_grande)
print(f"La casa más pequeña está ubicada en:")
print(casa_mas_pequeña)
# Out:
# La casa más grande está ubicada en:
#                address   surface
# 6794  Sevilla la Nueva  249000.0
# La casa más pequeña está ubicada en:
#                            address  surface
# 498  Calle Amparo,  Madrid Capital     15.0

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
pd.unique(ds['level5'])
# Out:
# array(['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte',
#        'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón',
#        'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón',
#        'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes',
#        'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles',
#        'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra',
#        'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón',
#        'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda',
#        'Villanueva de la Cañada', 'Villanueva del Pardillo',
#        'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez',
#        'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva',
#        'San Martín de la Vega', 'Villalbilla', 'Collado Villalba',
#        'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete',
#        'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo',
# ...

# %%
ds_population=ds.groupby('level5')
for level5,i in ds_population:
    print(level5)
# Out:
#  Madrid Capital
# Ajalvir
# Alcalá de Henares
# Alcobendas
# Alcorcón
# Aldea del Fresno
# Algete
# Alpedrete
# Ambite
# Anchuelo
# Aranjuez
# Arganda del Rey
# Arroyomolinos (Madrid)
# Batres
# Becerril de la Sierra
# Belmonte de Tajo
# Boadilla del Monte
# Braojos
# Brea de Tajo
# Brunete
# Buitrago del Lozoya
# Bustarviejo
# Cabanillas de la Sierra
# Cadalso de los Vidrios
# Camarma de Esteruelas
# Campo Real
# Canencia
# Carabaña
# Casarrubuelos
# Cenicientos
# Cercedilla
# Chapinería
# Chinchón
# Ciempozuelos
# Cobeña
# Collado Mediano
# Collado Villalba
# Colmenar Viejo
# Colmenar de Oreja
# Colmenar del Arroyo
# Colmenarejo
# Corpa
# Coslada
# Cubas de la Sagra
# Daganzo de Arriba
# El Atazar
# El Berrueco
# El Boalo - Cerceda – Mataelpino
# El Escorial
# El Molar (Madrid)
# El Vellón
# El Álamo
# Estremera
# Fresnedillas de la Oliva
# Fresno de Torote
# Fresno de Torote - Serracines
# Fuenlabrada
# Fuente El Saz de Jarama
# Fuentidueña de Tajo
# Galapagar
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
null=ds.isna()
null
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %%
print(ds.isnull().sum())
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
ds_new=ds.dropna(axis=1)
ds_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      15335 non-null  int64
#  1   id_realEstates  15335 non-null  int64
#  2   isNew           15335 non-null  bool
#  3   url_inmueble    15335 non-null  object
#  4   price           15335 non-null  int64
#  5   date            15335 non-null  object
#  6   address         15335 non-null  object
#  7   country         15335 non-null  object
#  8   level1          15335 non-null  object
#  9   level2          15335 non-null  object
#  10  level3          15335 non-null  object
#  11  level5          15335 non-null  object
#  12  upperLevel      15335 non-null  object
#  13  countryId       15335 non-null  int64
#  14  level1Id        15335 non-null  int64
#  15  level2Id        15335 non-null  int64
#  16  level3Id        15335 non-null  int64
# ...

# %%
ds.dropna()
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
dt_arroyomolinos=ds[ds['level5']=='Arroyomolinos (Madrid)']
media_arroyomolinos=dt_arroyomolinos['price'].mean()
print(f"Precio medio: {int(media_arroyomolinos)}€")
# Out:
# Precio medio: 294541€

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt
dt_arroyomolinos[['price','level5']].hist(bins=10)
plt.yticks(range(0,50,10))
plt.legend(['Casas Arroyomolinos'])
plt.show()

# %% [markdown]
# #Comentario al histograma#
#
# El gráfico nos muestra que el precio de la oferta inmobiliaria en Arroyomolinos oscila mayoritariamente entre los 250.000€ y 350.000€. Fuera de este rango la vivienda tiene a encarecerse, lo que nos indica que se trata de una zona atractiva para un cliente de alto nivel adquisitivo.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
dt_valdemorillo=ds[ds['level5']=='Valdemorillo']
media_valdemorillo=dt_valdemorillo['price'].mean()
dt_galapagar=ds[ds['level5']== 'Galapagar']
media_galapagar=dt_galapagar['price'].mean()
print(f"Precio medio: {int(media_valdemorillo)}€")
print(f"Precio medio: {int(media_galapagar)}€")
# Out:
# Precio medio: 363860€
# Precio medio: 360063€

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds['pps']=round(ds['price']/ds['surface'],2)
round(ds['pps'].mean(),2)
# Out:
# np.float64(2940.72)

# %%
dt_valdemorillo['pps']=dt_valdemorillo['price']/dt_valdemorillo['surface']
media_v=dt_valdemorillo['pps'].mean()
dt_galapagar['pps']=dt_galapagar['price']/dt_galapagar['surface']
media_g=dt_galapagar['pps'].mean()
media_v, media_g
# Out:
# /tmp/ipykernel_35921/3683459015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_valdemorillo['pps']=dt_valdemorillo['price']/dt_valdemorillo['surface']
# /tmp/ipykernel_35921/3683459015.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_galapagar['pps']=dt_galapagar['price']/dt_galapagar['surface']
# (np.float64(1317.9502109024986), np.float64(1606.3240303094024))

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='price',y='surface',label='Valdemorillo',data=dt_valdemorillo)
plt.scatter(x='price',y='surface',label='galapar',data=dt_galapagar)
plt.legend()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
len(ds['realEstate_name'].unique())
# Out:
# 1822

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
ds['level5'].value_counts().index[0]
# Out:
# ' Madrid Capital'

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
df_sur=ds[ds['level5'].isin(['Fuenlabrada','Leganés','Getafe','Alcorcón'])].reset_index(drop=True)

df_sur
# Out:
#      Unnamed: 0  id_realEstates  isNew  \
# 0             2       153867863  False
# 1             4       152776331  False
# 2            86       153152077  False
# 3            95       153995577  False
# 4           110       153586414  False
# ..          ...             ...    ...
# 902       15276       153903887  False
# 903       15292       151697757  False
# 904       15306       153902389  False
# 905       15323       153871864  False
# 906       15326       153901467  False
#
#                                realEstate_name  phone_realEstate  \
# 0            tecnocasa fuenlabrada ferrocarril       916358736.0
# 1            tecnocasa fuenlabrada ferrocarril       916358736.0
# 2                      sinergical inmobiliaria               NaN
# 3                              viviendas365com       911226014.0
# 4              area uno asesores inmobiliarios       912664081.0
# ..                                         ...               ...
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
a=sorted(list(df_sur['level5'].unique()))
b=df_sur.groupby('level5')['price'].mean()
plt.bar(a,b)
plt.show()
b
# Out:
# level5
# Alcorcón       230071.052632
# Fuenlabrada    177198.021459
# Getafe         265040.500000
# Leganés        208682.010309
# Name: price, dtype: float64

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
df_sur.groupby('level5')[['price','rooms','surface','bathrooms']].agg(['mean','var']).round(2)
# Out:
#                  price               rooms       surface          bathrooms  \
#                   mean           var  mean   var    mean      var      mean
# level5
# Alcorcón     230071.05  1.594783e+10  2.91  0.93  105.91  4244.32      1.62
# Fuenlabrada  177198.02  4.701021e+09  3.03  0.36  103.62  2264.64      1.45
# Getafe       265040.50  2.098267e+10  3.15  0.77  126.90  5828.11      1.87
# Leganés      208682.01  1.191394e+10  2.91  0.82  105.85  3987.48      1.52
#
#
#               var
# level5
# Alcorcón     0.59
# Fuenlabrada  0.35
# Getafe       0.66
# Leganés      0.55

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
idx_casas=df_sur.groupby('level5')['price'].idxmax()
df_casas_caras=df_sur.loc[idx_casas].reset_index(drop=True)
for i in range (len(df_casas_caras)):
    print(f"La casa más cara en {df_casas_caras['level5'][i]} se encuentra en {df_casas_caras['address'][i]} y cuesta {df_casas_caras['price'][i]} €")
# Out:
# La casa más cara en Alcorcón se encuentra en Alcorcón y cuesta 950000 €
# La casa más cara en Fuenlabrada se encuentra en Calle de Paulo Freire, 5, Fuenlabrada y cuesta 490000 €
# La casa más cara en Getafe se encuentra en Getafe y cuesta 1050000 €
# La casa más cara en Leganés se encuentra en Avenida Reina Sofía, Leganés y cuesta 650000 €

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
var_fuen=ds[ds['level5']=='Fuenlabrada'].reset_index(drop=True)
var_lega=ds[ds['level5']=='Leganés'].reset_index(drop=True)
var_geta=ds[ds['level5']=='Getafe'].reset_index(drop=True)
var_alco=ds[ds['level5']=='Alcorcón'].reset_index(drop=True)
max_fuen=var_fuen['price'].max()
max_lega=var_lega['price'].max()
max_geta=var_geta['price'].max()
max_alco=var_alco['price'].max()
var_fuen['normalizacion']=var_fuen['price']/max_fuen
var_lega['normalizacion']=var_lega['price']/max_lega
var_geta['normalizacion']=var_geta['price']/max_geta
var_alco['normalizacion']=var_alco['price']/max_alco
fig, graf = plt.subplots(nrows=2, ncols=2)
graf[0,0].hist(x=var_fuen['normalizacion'], alpha=0.6)
graf[0,0].title.set_text('Fuenlabrada')
graf[0,1].hist(x=var_alco['normalizacion'], alpha=0.6)
graf[0,1].title.set_text('Alcorcon')
graf[1,0].hist(x=var_geta['normalizacion'], alpha=0.6)
graf[1,0].title.set_text('Getafe')
graf[1,1].hist(x=var_lega['normalizacion'], alpha=0.6)
graf[1,1].title.set_text('Leganés')

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
df_sur_geta_alco=ds[ds['level5'].isin(['Getafe','Alcorcón'])].reset_index(drop=True)
df_sur_geta_alco.groupby('level5')['pps'].describe().round(2)
# Out:
#           count     mean     std     min      25%      50%      75%      max
# level5
# Alcorcón  173.0  2239.30  539.95  604.76  1904.08  2207.79  2472.73  3698.16
# Getafe    241.0  2066.32  741.87    0.00  1684.29  1973.33  2628.79  3827.16

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
var_tajo=ds[ds['level5']=='Belmonte de Tajo'].reset_index(drop=True)
var_boadilla=ds[ds['level5']=='Boadilla del Monte'].reset_index(drop=True)
var_braojos=ds[ds['level5']=='Braojos'].reset_index(drop=True)
var_brea=ds[ds['level5']=='Brea de Tajo'].reset_index(drop=True)
max_tajo=var_tajo['price'].max()
max_boadilla=var_boadilla['price'].max()
max_braojos=var_braojos['price'].max()
max_brea=var_brea['price'].max()
var_tajo['normalizacion']=var_tajo['price']/max_tajo
var_boadilla['normalizacion']=var_boadilla['price']/max_boadilla
var_braojos['normalizacion']=var_braojos['price']/max_braojos
var_brea['normalizacion']=var_brea['price']/max_brea
fig, graf = plt.subplots(nrows=4, ncols=2)
graf[0,0].hist(x=var_fuen['normalizacion'], alpha=0.6)
graf[0,0].title.set_text('Fuenlabrada')
graf[0,1].hist(x=var_alco['normalizacion'], alpha=0.6)
graf[0,1].title.set_text('Alcorcon')
graf[1,0].hist(x=var_geta['normalizacion'], alpha=0.6)
graf[1,0].title.set_text('Getafe')
graf[1,1].hist(x=var_lega['normalizacion'], alpha=0.6)
graf[1,1].title.set_text('Leganés')
graf[2,0].hist(x=var_tajo['normalizacion'], alpha=0.6)
graf[2,0].title.set_text('Belmonte de Tajo')
graf[2,1].hist(x=var_boadilla['normalizacion'], alpha=0.6)
graf[2,1].title.set_text('Boadilla del Monte')
graf[3,0].hist(x=var_braojos['normalizacion'], alpha=0.6)
graf[3,0].title.set_text('Braojos')
graf[3,1].hist(x=var_brea['normalizacion'], alpha=0.6)
graf[3,1].title.set_text('Brea de Tajo')

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps,Marker


# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
#basemap=basemaps.OpenStreetMap.Mapnik
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
# 'latitude', 'longitude'
coord=df_sur[['latitude', 'longitude']]
dict_coord=coord.to_dict('index')
dict_coord
# marcador=[40.965, -5.664]
# marker = Marker(location=marcador, draggable=True)
# m.add_layer(marker);

for m in dict_coord.keys():
    market_out = dict_coord.get(m)
    market_in = [market_out.get('latitude'), market_out.get('longitude')]
    marker = Marker(location=market_in, draggable=True)
    map.add(marker)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
